# %%
import pandas as pd


df = pd.read_csv(
    "products.csv"
)


print(df.head())


print(
    "Rows:",
    df.count()[0]
)


print(
    "Columns:",
    len(df.columns)
)
# Out:
#   product_id   product_name     category sub_category   brand  \
# 0      P1001    Dark Mobile  Electronics       Mobile    Dell
# 1      P1002   Never Laptop  Electronics       Laptop    Nike
# 2      P1003  Another Shoes      Fashion        Shoes   Apple
# 3      P1004    Even Laptop  Electronics       Laptop  Adidas
# 4      P1005  Should Mobile  Electronics       Mobile   Apple
#
#                        supplier  price  discount_percent  stock_quantity  \
# 0                   Griffin Inc  35177                35             243
# 1               Hardin-Williams  92347                31             811
# 2         Munoz, Cox and Howard  31211                22             203
# 3  Gonzalez, Orozco and Webster   8631                20             429
# 4                 Oneill-Powell  14274                39             918
#
#    rating  reviews_count  weight_kg   color      size   material  \
# 0     4.7           9805       7.03   Black     Large  Aluminium
# ...
